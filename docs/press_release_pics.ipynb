# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Scatter (soft navy)
plt.scatter(x, y, alpha=0.3, s=15, color="#2C3E50")

# Trend line (slightly lighter blue for contrast)
plt.plot(x_sorted, y_line, linewidth=2, color="#2C3E50")

plt.title("WTI Spot Price Changes vs Gas Prices 4 Weeks Later", fontsize=14)
plt.xlabel("WTI % Change (4 Weeks)")
plt.ylabel("Gas Price 4 Weeks Ahead (USD)")
plt.legend(["Trend Line", "Data Points"], loc="upper right")

ax = plt.gca()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

plt.tight_layout()
plt.savefig("wti_gas_price_trend.png", dpi=300)
plt.show()
